# %% [markdown]
# This script will contain the following:
#
# 1. Importing libraries
# 2. Importing Data
# 3.

# %% [markdown]
# 1. Importing libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime as dt

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.7.1'

# %% [markdown]
# 2. Importing Data

# %%
df = pd.read_csv('new_2022_data.csv', index_col = 0)
# Out:
# C:\Users\nehma\AppData\Local\Temp\ipykernel_2396\3531589899.py:1: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('new_2022_data.csv', index_col = 0)

# %%
#checking data

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  55262E4365A955A2   classic_bike  2022-01-18 08:23:52  2022-01-18 08:28:18
# 1  D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22  2022-01-21 09:05:44
# 2  D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32  2022-01-22 14:53:18
# 3  E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47  2022-01-19 14:54:02
# 4  2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06  2022-01-16 14:44:06
#
#         start_station_name start_station_id           end_station_name  \
# 0  Boerum Pl\t& Pacific St          4488.09  Clinton St & Joralemon St
# 1          E 12 St & Ave C          5616.08         E 10 St & Avenue A
# 2          W 21 St & 6 Ave          6140.05           W 44 St & 11 Ave
# 3           38 St & 30 Ave          6850.01       Crescent St & 30 Ave
# 4   Pacific St & Nevins St          4362.04    Clinton St & Tillary St
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual  \
# 0        4605.04  40.688489 -73.991160  40.692395 -73.993379        member
# 1        5659.05  40.727243 -73.976831  40.727408 -73.981420        member
# 2        6756.05  40.741740 -73.994156  40.762009 -73.996975        member
# 3        6958.06  40.764175 -73.915840  40.768692 -73.924957        member
# 4        4748.07  40.685376 -73.983021  40.696233 -73.991421        member
#
#             start_time        date  avgTemp _merge
# 0  2022-01-18 08:23:52  2022-01-18     -2.0   both
# 1  2022-01-21 09:03:22  2022-01-21    -10.0   both
# 2  2022-01-22 14:28:32  2022-01-22     -5.0   both
# 3  2022-01-19 14:49:47  2022-01-19     -1.1   both
# 4  2022-01-16 14:36:06  2022-01-16     -6.9   both

# %%
df.tail ()
# Out:
#                    ride_id rideable_type           started_at  \
# 12604018  DB0F2BC747C2E6A9  classic_bike  2022-06-03 17:41:17
# 12604019  F8F48CB0DBE7F956  classic_bike  2022-06-29 15:17:52
# 12604020  2EB7603C8DD7E2AE  classic_bike  2022-06-23 17:30:19
# 12604021  797A16D3D20E632A  classic_bike  2022-06-18 14:00:31
# 12604022  E0136D48AA70F85D  classic_bike                    2
#
#                      ended_at       start_station_name start_station_id  \
# 12604018  2022-06-03 17:48:05     Broadway & Morris St          5033.01
# 12604019  2022-06-29 15:46:11         W 33 St & 10 Ave          6492.04
# 12604020  2022-06-23 18:05:13  E 53 St & Lexington Ave          6617.09
# 12604021  2022-06-18 14:06:23   Forsyth St & Broome St          5453.05
# 12604022                  NaN                      NaN              NaN
#
#                    end_station_name end_station_id  start_lat  start_lng  \
# 12604018      West St & Chambers St        5329.03  40.705945 -74.013219
# 12604019      West St & Chambers St        5329.03  40.753773 -73.999376
# 12604020      West St & Chambers St        5329.03  40.758281 -73.970694
# 12604021  W Broadway & W Houston St        5644.05  40.718939 -73.992663
# 12604022                        NaN            NaN        NaN        NaN
#
#             end_lat    end_lng member_casual           start_time        date  \
# 12604018  40.717548 -74.013221        member  2022-06-03 17:41:17  2022-06-03
# 12604019  40.717548 -74.013221        casual  2022-06-29 15:17:52  2022-06-29
# 12604020  40.717548 -74.013221        member  2022-06-23 17:30:19  2022-06-23
# 12604021  40.726378 -74.000472        member  2022-06-18 14:00:31  2022-06-18
# 12604022        NaN        NaN           NaN                  NaN         NaN
#
#           avgTemp _merge
# 12604018     21.0   both
# 12604019     24.9   both
# 12604020     25.0   both
# 12604021     19.8   both
# 12604022      NaN    NaN

# %%
df.shape
# Out:
# (12604023, 17)

# %%
df.drop(columns = {'_merge'}, inplace = True)

# %%
df.head(5)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  55262E4365A955A2   classic_bike  2022-01-18 08:23:52  2022-01-18 08:28:18
# 1  D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22  2022-01-21 09:05:44
# 2  D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32  2022-01-22 14:53:18
# 3  E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47  2022-01-19 14:54:02
# 4  2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06  2022-01-16 14:44:06
#
#         start_station_name start_station_id           end_station_name  \
# 0  Boerum Pl\t& Pacific St          4488.09  Clinton St & Joralemon St
# 1          E 12 St & Ave C          5616.08         E 10 St & Avenue A
# 2          W 21 St & 6 Ave          6140.05           W 44 St & 11 Ave
# 3           38 St & 30 Ave          6850.01       Crescent St & 30 Ave
# 4   Pacific St & Nevins St          4362.04    Clinton St & Tillary St
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual  \
# 0        4605.04  40.688489 -73.991160  40.692395 -73.993379        member
# 1        5659.05  40.727243 -73.976831  40.727408 -73.981420        member
# 2        6756.05  40.741740 -73.994156  40.762009 -73.996975        member
# 3        6958.06  40.764175 -73.915840  40.768692 -73.924957        member
# 4        4748.07  40.685376 -73.983021  40.696233 -73.991421        member
#
#             start_time        date  avgTemp
# 0  2022-01-18 08:23:52  2022-01-18     -2.0
# 1  2022-01-21 09:03:22  2022-01-21    -10.0
# 2  2022-01-22 14:28:32  2022-01-22     -5.0
# 3  2022-01-19 14:49:47  2022-01-19     -1.1
# 4  2022-01-16 14:36:06  2022-01-16     -6.9

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# start_time             object
# date                   object
# avgTemp               float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at                    object
# ended_at                      object
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# start_time                    object
# date                  datetime64[ns]
# avgTemp                      float64
# dtype: object

# %% [markdown]
# 3.Basic Plotting with Pandas

# %%
df_temp = df.set_index('date')

# %%
df_temp.head()
# Out:
#                      ride_id  rideable_type           started_at  \
# date
# 2022-01-18  55262E4365A955A2   classic_bike  2022-01-18 08:23:52
# 2022-01-21  D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22
# 2022-01-22  D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32
# 2022-01-19  E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47
# 2022-01-16  2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06
#
#                        ended_at       start_station_name start_station_id  \
# date
# 2022-01-18  2022-01-18 08:28:18  Boerum Pl\t& Pacific St          4488.09
# 2022-01-21  2022-01-21 09:05:44          E 12 St & Ave C          5616.08
# 2022-01-22  2022-01-22 14:53:18          W 21 St & 6 Ave          6140.05
# 2022-01-19  2022-01-19 14:54:02           38 St & 30 Ave          6850.01
# 2022-01-16  2022-01-16 14:44:06   Pacific St & Nevins St          4362.04
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# date
# 2022-01-18  Clinton St & Joralemon St        4605.04  40.688489 -73.991160
# 2022-01-21         E 10 St & Avenue A        5659.05  40.727243 -73.976831
# 2022-01-22           W 44 St & 11 Ave        6756.05  40.741740 -73.994156
# 2022-01-19       Crescent St & 30 Ave        6958.06  40.764175 -73.915840
# 2022-01-16    Clinton St & Tillary St        4748.07  40.685376 -73.983021
#
#               end_lat    end_lng member_casual           start_time  avgTemp
# date
# 2022-01-18  40.692395 -73.993379        member  2022-01-18 08:23:52     -2.0
# 2022-01-21  40.727408 -73.981420        member  2022-01-21 09:03:22    -10.0
# 2022-01-22  40.762009 -73.996975        member  2022-01-22 14:28:32     -5.0
# 2022-01-19  40.768692 -73.924957        member  2022-01-19 14:49:47     -1.1
# 2022-01-16  40.696233 -73.991421        member  2022-01-16 14:36:06     -6.9

# %%
df_temp['avgTemp'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
#I do not understand why the line graph looks like this

# %% [markdown]
# 4. Procedural Approach

# %%
plt.plot(df_temp['avgTemp'])
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.title('Temperatures daily for 2022')
plt.plot(df_temp['avgTemp'])
plt.show()

# %%
plt.title('Temperatures daily for 2018')
plt.figure(figsize=(10,4))
plt.plot(df_temp['avgTemp'])
plt.show()

# %% [markdown]
# 5. Aggregate trips

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'start_time', 'date', 'avgTemp'],
#       dtype='object')

# %%
# Groupby the count of the trips 

df_group = pd.DataFrame(df.groupby(['date'])['ride_id'].count()).reset_index()

# %%
df_group.head()
# Out:
#         date  ride_id
# 0 2022-01-01    20895
# 1 2022-01-02    44234
# 2 2022-01-03    34126
# 3 2022-01-04    37879
# 4 2022-01-05    35080

# %%
df_group.rename(columns = {'ride_id':'bike_rides_daily'}, inplace = True)
df = df.merge(df_group, on = "date", how = 'outer', indicator = True)
print(df['_merge'].value_counts(dropna = False))
print("Shape of January 1st is", df[df['date'] == '2022-01-01'].shape) # Check 
print("Shape of January 2nd is", df[df['date'] == '2022-01-02'].shape) # Second check 

df_temp = df.set_index('date')

print(df_temp.columns)
# Out:
# _merge
# both          12604022
# left_only            1
# right_only           0
# Name: count, dtype: int64
# Shape of January 1st is (20895, 18)
# Shape of January 2nd is (44234, 18)
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'start_time', 'avgTemp', 'bike_rides_daily', '_merge'],
#       dtype='object')

# %%
df_temp.head()
# Out:
#                      ride_id  rideable_type           started_at  \
# date
# NaT         E0136D48AA70F85D   classic_bike                    2
# 2022-01-01  68FDAB9B6656A4DF   classic_bike  2022-01-01 05:11:08
# 2022-01-01  91C955306D2CF8A6  electric_bike  2022-01-01 20:54:00
# 2022-01-01  B379B77AEB677F2A  electric_bike  2022-01-01 15:48:06
# 2022-01-01  1F1368CC1EEDA296  electric_bike  2022-01-01 02:32:52
#
#                        ended_at        start_station_name start_station_id  \
# date
# NaT                         NaN                       NaN              NaN
# 2022-01-01  2022-01-01 05:15:25           W 21 St & 6 Ave          6140.05
# 2022-01-01  2022-01-01 21:06:39  Bedford Ave & Nassau Ave          5550.05
# 2022-01-01  2022-01-01 16:44:21  Central Park W & W 91 St          7453.01
# 2022-01-01  2022-01-01 02:44:51    West End Ave & W 78 St          7340.07
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# date
# NaT                          NaN            NaN        NaN        NaN
# 2022-01-01       W 11 St & 6 Ave        5914.03  40.741740 -73.994156
# 2022-01-01  Sharon St & Olive St        5323.05  40.723117 -73.952123
# 2022-01-01       5 Ave & E 87 St        7323.09  40.788665 -73.966801
# 2022-01-01      W 44 St & 11 Ave        6756.05  40.783786 -73.981687
#
#               end_lat    end_lng member_casual           start_time  avgTemp  \
# date
# NaT               NaN        NaN           NaN                  NaN      NaN
# 2022-01-01  40.735324 -73.998004        member  2022-01-01 05:11:08      2.0
# 2022-01-01  40.715353 -73.938560        member  2022-01-01 20:54:00      2.0
# 2022-01-01  40.782323 -73.959875        casual  2022-01-01 15:48:06      2.0
# 2022-01-01  40.762009 -73.996975        casual  2022-01-01 02:32:52      2.0
#
#             bike_rides_daily     _merge
# date
# NaT                      NaN  left_only
# 2022-01-01           20895.0       both
# 2022-01-01           20895.0       both
# 2022-01-01           20895.0       both
# 2022-01-01           20895.0       both

# %%
plt.figure(figsize=(10,5))
plt.title('Temperature per trips')
plt.plot(df_temp['avgTemp'])
plt.plot(df_temp['bike_rides_daily'], color = 'red')
plt.show()

# %% [markdown]
# The code follows the procedural paradigm, where each line of code is executed sequentially to achieve the desired visualization. The plt.plot() function is used to plot the temperature and bike ride data, and plt.title() is used to set the title of the plot. Finally, plt.show() is used to display the plot to the user.

# %% [markdown]
# 6. OO Approach

# %%
# Create figure and axis objects with subplots()

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "red")

# %%
# Create figure and axis objects with subplots()

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "red")
ax.plot(df_temp['avgTemp'], color = 'blue')

# %%
# Create figure and axis objects with subplots()

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "red")
ax.plot(df_temp['avgTemp'], color = 'blue')

# %% [markdown]
# 7. Final Dual Plot

# %%
# Create figure and axis objects with subplots() and details

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "navy")
ax.set_xlabel("Year 2022", fontsize = 14) # set x-axis label
ax.set_ylabel("Bike rides daily",color = "navy", fontsize = 14) # set y-axis label

# Here is where we create the dual axis - initialize a twin object for two different y-axis on the sample plot
ax2 = ax.twinx()

# Make a plot with the temperatues on the y-axis using second axis object
ax2.plot(df_temp["avgTemp"], color = "red")
ax2.set_ylabel("Average temperatures", color = "red",fontsize=14)
plt.title('Temperature and trips in 2022', fontsize = 18)
plt.show()

# %%
plt.style.use('ggplot')

# %%
# Create figure and axis objects with subplots() and details

fig,ax = plt.subplots(2, figsize =(8, 6))

# Make a plot of the bike rides
ax[0].plot(df_temp['bike_rides_daily'],color = "navy")
ax[0].set_ylabel("Bike rides daily",color = "navy", fontsize = 14) # set y-axis label

# Make a plot with the temperatues on the y-axis using second axis object
ax[1].plot(df_temp["avgTemp"], color = "red")
ax[1].set_ylabel("Average temperatures", color = "red",fontsize=14)
plt.suptitle('Temperature and trips in 2022', fontsize = 18)

plt.show()

# %%
# save the plot as a file
fig.savefig('trips_temperatures_dual_line.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %%
# Saving the histogram
plt.figure(figsize=(8, 6))
plt.hist(df['avgTemp'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Average Temperature')
plt.xlabel('Average Temperature')
plt.ylabel('Frequency')
plt.grid(True)
plt.savefig('avgTemp_histogram.png')  # Save the figure as a PNG file
plt.show()

# Saving the figure with two axes
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plotting the bar chart
start_station_counts = df['start_station_name'].value_counts().head(10)
axs[0].bar(start_station_counts.index, start_station_counts.values, color='green')
axs[0].set_title('Top 10 Start Stations')
axs[0].set_xlabel('Start Station Name')
axs[0].set_ylabel('Count')
axs[0].tick_params(axis='x', rotation=90)

# Plotting the pie chart
rideable_type_counts = df['rideable_type'].value_counts()
axs[1].pie(rideable_type_counts.values, labels=rideable_type_counts.index, autopct='%1.1f%%', startangle=140)
axs[1].set_title('Rideable Type Distribution')

plt.tight_layout()
plt.savefig('two_axes_figure.png')  # Save the figure with two axes as a PNG file
plt.show()
